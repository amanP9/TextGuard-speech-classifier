# %%
import numpy as np
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
# from preprocess import preprocess_text
# from preprocess import preprocess_text
import joblib
# from text_preprocessing import preprocess_text

# %%
df_hate_1 = pd.read_csv("Hate_Speeches_1.csv")
df_hate_2 = pd.read_csv("Hate_Speeches_2.csv")
df_hate_3 = pd.read_csv("Hate_Speeches_3.csv")
df_hate_4 = pd.read_csv("Hate_Speeches_4.csv")
df_normal_5 = pd.read_csv("Normal_Speeches_1.csv")
df_normal_6 = pd.read_csv("Normal_Speeches_2.csv")
df_normal_7 = pd.read_csv("Normal_Speeches_3.csv")
df_normal_8 = pd.read_csv("Normal_Speeches_4.csv")
# df_offensive_9 = pd.read_csv("Offensive_Speeches_1.csv")
# df_offensive_10 = pd.read_csv("Offensive_Speeches_2.csv")
# df_offensive_11 = pd.read_csv("Offensive_Speeches_3.csv")
# df_offensive_12 = pd.read_csv("Offensive_Speeches_4.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-13b5120fc7e6> in <cell line: 1>()
# ----> 1 df_hate_1 = pd.read_csv("Hate_Speeches_1.csv")
#       2 df_hate_2 = pd.read_csv("Hate_Speeches_2.csv")
#       3 df_hate_3 = pd.read_csv("Hate_Speeches_3.csv")
#       4 df_hate_4 = pd.read_csv("Hate_Speeches_4.csv")
#       5 df_normal_5 = pd.read_csv("Normal_Speeches_1.csv")
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Hate_Speeches_1.csv'

# %%
df_hate_1['speech'] = 'hate_or_offensive'
df_hate_2['speech'] = 'hate_or_offensive'
df_hate_3['speech'] = 'hate_or_offensive'
df_hate_4['speech'] = 'hate_or_offensive'

df_normal_5['speech'] = 'normal'
df_normal_6['speech'] = 'normal'
df_normal_7['speech'] = 'normal'
df_normal_8['speech'] = 'normal'

# df_offensive_9['speech'] = 'hate_or_offensive'
# df_offensive_10['speech'] = 'hate_or_offensive'
# df_offensive_11['speech'] = 'hate_or_offensive'
# df_offensive_12['speech'] = 'hate_or_offensive'

# %%
# frames = [df_hate_1, df_hate_2, df_hate_3, df_hate_4, df_normal_5, df_normal_6, df_normal_7, df_normal_8, df_offensive_9, df_offensive_10, df_offensive_11, df_offensive_12]
# df = pd.concat(frames)
frames = [df_hate_1, df_hate_2, df_hate_3, df_hate_4, df_normal_5, df_normal_6, df_normal_7, df_normal_8]
df = pd.concat(frames)

# %%
df.head(10)
# Out:
#        conversation_id                created_at  favorite_count  \
# 0  1624652050448674816  2023-02-12T06:10:08.000Z             115
# 1  1624649867720007680  2023-02-12T06:01:27.000Z               6
# 2  1624647737039007750  2023-02-12T05:52:59.000Z            1474
# 3  1624560613807607808  2023-02-12T00:06:47.000Z              30
# 4  1624540978047553536  2023-02-11T22:48:46.000Z              90
# 5  1624490492644794370  2023-02-11T19:28:09.000Z               0
# 6  1624218947242565633  2023-02-11T01:29:08.000Z             384
# 7  1624214848451100677  2023-02-11T01:12:50.000Z             288
# 8  1624156000369446912  2023-02-10T21:19:00.000Z           15939
# 9  1623653902523441156  2023-02-09T12:03:51.000Z            1463
#
#                                            full_text hashtags/0   hashtags/1  \
# 0  another day to hate some kt3umes. they were ne...        NaN          NaN
# 1  #SMG4's:\n Twitter comments               vs  ...       SMG4          NaN
# 2  I hate it whenever I see “mataba ka!” comments...        NaN          NaN
# 3  ain’t no way they deleted my comments under th...        NaN          NaN
# 4  Just incase any of you wanna add this one to y...        NaN          NaN
# 5  Honestly done and disappointed with @GenesysGo...     solana  shadowdrive
# 6  He's A Psycho! - Why David Goggins Records Him...        NaN          NaN
# 7  Comments are fucking horrid on TikTok I hate m...        NaN          NaN
# 8  HELLO??? ALL THE CONCEPT SKETCHES FOR FREE??? ...        NaN          NaN
# 9  I love how much these pics trigger ppl. Going ...        NaN          NaN
#
#   hashtags/2 hashtags/3 hashtags/4 hashtags/5  ...  \
# 0        NaN        NaN        NaN        NaN  ...
# 1        NaN        NaN        NaN        NaN  ...
# 2        NaN        NaN        NaN        NaN  ...
# 3        NaN        NaN        NaN        NaN  ...
# 4        NaN        NaN        NaN        NaN  ...
# 5  genesysgo        NaN        NaN        NaN  ...
# 6        NaN        NaN        NaN        NaN  ...
# 7        NaN        NaN        NaN        NaN  ...
# 8        NaN        NaN        NaN        NaN  ...
# 9        NaN        NaN        NaN        NaN  ...
#
#   user_mentions/43/screen_name user_mentions/44/id_str user_mentions/44/name  \
# 0                          NaN                     NaN                   NaN
# 1                          NaN                     NaN                   NaN
# 2                          NaN                     NaN                   NaN
# 3                          NaN                     NaN                   NaN
# 4                          NaN                     NaN                   NaN
# 5                          NaN                     NaN                   NaN
# 6                          NaN                     NaN                   NaN
# 7                          NaN                     NaN                   NaN
# 8                          NaN                     NaN                   NaN
# 9                          NaN                     NaN                   NaN
#
#   user_mentions/44/screen_name user_mentions/45/id_str  user_mentions/45/name  \
# 0                          NaN                     NaN                    NaN
# 1                          NaN                     NaN                    NaN
# 2                          NaN                     NaN                    NaN
# 3                          NaN                     NaN                    NaN
# 4                          NaN                     NaN                    NaN
# 5                          NaN                     NaN                    NaN
# 6                          NaN                     NaN                    NaN
# 7                          NaN                     NaN                    NaN
# 8                          NaN                     NaN                    NaN
# 9                          NaN                     NaN                    NaN
#
#   user_mentions/45/screen_name user_mentions/46/id_str user_mentions/46/name  \
# 0                          NaN                     NaN                   NaN
# 1                          NaN                     NaN                   NaN
# 2                          NaN                     NaN                   NaN
# 3                          NaN                     NaN                   NaN
# 4                          NaN                     NaN                   NaN
# 5                          NaN                     NaN                   NaN
# 6                          NaN                     NaN                   NaN
# 7                          NaN                     NaN                   NaN
# 8                          NaN                     NaN                   NaN
# 9                          NaN                     NaN                   NaN
#
#   user_mentions/46/screen_name
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
#
# [10 rows x 245 columns]

# %%
df.columns.tolist()
# Out:
# ['conversation_id',
#  'created_at',
#  'favorite_count',
#  'full_text',
#  'hashtags/0',
#  'hashtags/1',
#  'hashtags/2',
#  'hashtags/3',
#  'hashtags/4',
#  'hashtags/5',
#  'hashtags/6',
#  'hashtags/7',
#  'hashtags/8',
#  'hashtags/9',
#  'hashtags/10',
#  'id',
#  'media/0/media_url',
#  'media/0/type',
#  'media/1/media_url',
#  'media/1/type',
#  'media/2/media_url',
#  'media/2/type',
#  'media/3/media_url',
#  'media/3/type',
#  'reply_count',
#  'retweet_count',
#  'startUrl',
#  'symbols/0',
#  'url',
#  'urls/0/display_url',
#  'urls/0/expanded_url',
#  'urls/0/url',
#  'urls/1/display_url',
#  'urls/1/expanded_url',
#  'urls/1/url',
#  'user/advertiser_account_type',
#  'user/blocked_by',
#  'user/blocking',
#  'user/business_profile_state',
#  'user/can_dm',
#  'user/contributors_enabled',
#  'user/created_at',
#  'user/default_profile_image',
#  'user/description',
#  'user/ext_has_nft_avatar',
#  'user/ext_is_blue_verified',
#  'user/ext_verified_type',
#  'user/fast_followers_count',
#  'user/favourites_count',
#  'user/follow_request_sent',
#  'user/followed_by',
#  'user/followers_count',
#  'user/following',
#  'user/friends_count',
#  'user/geo_enabled',
#  'user/has_custom_timelines',
#  'user/id',
#  'user/id_str',
#  'user/is_translation_enabled',
#  'user/is_translator',
#  'user/lang',
#  'user/listed_count',
#  'user/location',
#  'user/media_count',
#  'user/muting',
#  'user/name',
#  'user/normal_followers_count',
#  'user/notifications',
#  'user/profile_background_color',
#  'user/profile_background_image_url',
#  'user/profile_background_image_url_https',
#  'user/profile_background_tile',
#  'user/profile_banner_extensions_sensitive_media_warning',
#  'user/profile_banner_url',
#  'user/profile_image_extensions_sensitive_media_warning',
#  'user/profile_image_url',
#  'user/profile_image_url_https',
#  'user/profile_sidebar_border_color',
#  'user/profile_sidebar_fill_color',
#  'user/profile_text_color',
#  'user/profile_use_background_image',
#  'user/protected',
#  'user/require_some_consent',
#  'user/screen_name',
#  'user/statuses_count',
#  'user/time_zone',
#  'user/translator_type',
#  'user/url',
#  'user/utc_offset',
#  'user/verified',
#  'user/want_retweets',
#  'user_mentions/0/id_str',
#  'user_mentions/0/name',
#  'user_mentions/0/screen_name',
#  'user_mentions/1/id_str',
#  'user_mentions/1/name',
#  'user_mentions/1/screen_name',
#  'user_mentions/2/id_str',
#  'user_mentions/2/name',
#  'user_mentions/2/screen_name',
#  'user_mentions/3/id_str',
#  'user_mentions/3/name',
#  'user_mentions/3/screen_name',
#  'user_mentions/4/id_str',
#  'user_mentions/4/name',
#  'user_mentions/4/screen_name',
#  'user_mentions/5/id_str',
#  'user_mentions/5/name',
#  'user_mentions/5/screen_name',
#  'user_mentions/6/id_str',
#  'user_mentions/6/name',
#  'user_mentions/6/screen_name',
#  'user_mentions/7/id_str',
#  'user_mentions/7/name',
#  'user_mentions/7/screen_name',
#  'user_mentions/8/id_str',
#  'user_mentions/8/name',
#  'user_mentions/8/screen_name',
#  'user_mentions/9/id_str',
#  'user_mentions/9/name',
#  'user_mentions/9/screen_name',
#  'user_mentions/10/id_str',
#  'user_mentions/10/name',
#  'user_mentions/10/screen_name',
#  'view_count',
#  'speech',
#  'hashtags/11',
#  'hashtags/12',
#  'hashtags/13',
#  'hashtags/14',
#  'hashtags/15',
#  'hashtags/16',
#  'hashtags/17',
#  'hashtags/18',
#  'hashtags/19',
#  'hashtags/20',
#  'hashtags/21',
#  'user_mentions/11/id_str',
#  'user_mentions/11/name',
#  'user_mentions/11/screen_name',
#  'user_mentions/12/id_str',
#  'user_mentions/12/name',
#  'user_mentions/12/screen_name',
#  'user_mentions/13/id_str',
#  'user_mentions/13/name',
#  'user_mentions/13/screen_name',
#  'user_mentions/14/id_str',
#  'user_mentions/14/name',
#  'user_mentions/14/screen_name',
#  'user_mentions/15/id_str',
#  'user_mentions/15/name',
#  'user_mentions/15/screen_name',
#  'user_mentions/16/id_str',
#  'user_mentions/16/name',
#  'user_mentions/16/screen_name',
#  'user_mentions/17/id_str',
#  'user_mentions/17/name',
#  'user_mentions/17/screen_name',
#  'user_mentions/18/id_str',
#  'user_mentions/18/name',
#  'user_mentions/18/screen_name',
#  'user_mentions/19/id_str',
#  'user_mentions/19/name',
#  'user_mentions/19/screen_name',
#  'user_mentions/20/id_str',
#  'user_mentions/20/name',
#  'user_mentions/20/screen_name',
#  'user_mentions/21/id_str',
#  'user_mentions/21/name',
#  'user_mentions/21/screen_name',
#  'user_mentions/22/id_str',
#  'user_mentions/22/name',
#  'user_mentions/22/screen_name',
#  'user_mentions/23/id_str',
#  'user_mentions/23/name',
#  'user_mentions/23/screen_name',
#  'user_mentions/24/id_str',
#  'user_mentions/24/name',
#  'user_mentions/24/screen_name',
#  'user_mentions/25/id_str',
#  'user_mentions/25/name',
#  'user_mentions/25/screen_name',
#  'user_mentions/26/id_str',
#  'user_mentions/26/name',
#  'user_mentions/26/screen_name',
#  'user_mentions/27/id_str',
#  'user_mentions/27/name',
#  'user_mentions/27/screen_name',
#  'user_mentions/28/id_str',
#  'user_mentions/28/name',
#  'user_mentions/28/screen_name',
#  'user_mentions/29/id_str',
#  'user_mentions/29/name',
#  'user_mentions/29/screen_name',
#  'user_mentions/30/id_str',
#  'user_mentions/30/name',
#  'user_mentions/30/screen_name',
#  'user_mentions/31/id_str',
#  'user_mentions/31/name',
#  'user_mentions/31/screen_name',
#  'user_mentions/32/id_str',
#  'user_mentions/32/name',
#  'user_mentions/32/screen_name',
#  'user_mentions/33/id_str',
#  'user_mentions/33/name',
#  'user_mentions/33/screen_name',
#  'user_mentions/34/id_str',
#  'user_mentions/34/name',
#  'user_mentions/34/screen_name',
#  'user_mentions/35/id_str',
#  'user_mentions/35/name',
#  'user_mentions/35/screen_name',
#  'user_mentions/36/id_str',
#  'user_mentions/36/name',
#  'user_mentions/36/screen_name',
#  'user_mentions/37/id_str',
#  'user_mentions/37/name',
#  'user_mentions/37/screen_name',
#  'user_mentions/38/id_str',
#  'user_mentions/38/name',
#  'user_mentions/38/screen_name',
#  'user_mentions/39/id_str',
#  'user_mentions/39/name',
#  'user_mentions/39/screen_name',
#  'user_mentions/40/id_str',
#  'user_mentions/40/name',
#  'user_mentions/40/screen_name',
#  'user_mentions/41/id_str',
#  'user_mentions/41/name',
#  'user_mentions/41/screen_name',
#  'user_mentions/42/id_str',
#  'user_mentions/42/name',
#  'user_mentions/42/screen_name',
#  'user_mentions/43/id_str',
#  'user_mentions/43/name',
#  'user_mentions/43/screen_name',
#  'user_mentions/44/id_str',
#  'user_mentions/44/name',
#  'user_mentions/44/screen_name',
#  'user_mentions/45/id_str',
#  'user_mentions/45/name',
#  'user_mentions/45/screen_name',
#  'user_mentions/46/id_str',
#  'user_mentions/46/name',
#  'user_mentions/46/screen_name']

# %%
df.insert(4, 'speech', df.pop('speech'))
# Out:
# <ipython-input-7-5bb44bd9e284>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(4, 'speech', df.pop('speech'))

# %%
df.head(10)
# Out:
#        conversation_id                created_at  favorite_count  \
# 0  1624652050448674816  2023-02-12T06:10:08.000Z             115
# 1  1624649867720007680  2023-02-12T06:01:27.000Z               6
# 2  1624647737039007750  2023-02-12T05:52:59.000Z            1474
# 3  1624560613807607808  2023-02-12T00:06:47.000Z              30
# 4  1624540978047553536  2023-02-11T22:48:46.000Z              90
# 5  1624490492644794370  2023-02-11T19:28:09.000Z               0
# 6  1624218947242565633  2023-02-11T01:29:08.000Z             384
# 7  1624214848451100677  2023-02-11T01:12:50.000Z             288
# 8  1624156000369446912  2023-02-10T21:19:00.000Z           15939
# 9  1623653902523441156  2023-02-09T12:03:51.000Z            1463
#
#                                            full_text             speech  \
# 0  another day to hate some kt3umes. they were ne...  hate_or_offensive
# 1  #SMG4's:\n Twitter comments               vs  ...  hate_or_offensive
# 2  I hate it whenever I see “mataba ka!” comments...  hate_or_offensive
# 3  ain’t no way they deleted my comments under th...  hate_or_offensive
# 4  Just incase any of you wanna add this one to y...  hate_or_offensive
# 5  Honestly done and disappointed with @GenesysGo...  hate_or_offensive
# 6  He's A Psycho! - Why David Goggins Records Him...  hate_or_offensive
# 7  Comments are fucking horrid on TikTok I hate m...  hate_or_offensive
# 8  HELLO??? ALL THE CONCEPT SKETCHES FOR FREE??? ...  hate_or_offensive
# 9  I love how much these pics trigger ppl. Going ...  hate_or_offensive
#
#   hashtags/0   hashtags/1 hashtags/2 hashtags/3 hashtags/4  ...  \
# 0        NaN          NaN        NaN        NaN        NaN  ...
# 1       SMG4          NaN        NaN        NaN        NaN  ...
# 2        NaN          NaN        NaN        NaN        NaN  ...
# 3        NaN          NaN        NaN        NaN        NaN  ...
# 4        NaN          NaN        NaN        NaN        NaN  ...
# 5     solana  shadowdrive  genesysgo        NaN        NaN  ...
# 6        NaN          NaN        NaN        NaN        NaN  ...
# 7        NaN          NaN        NaN        NaN        NaN  ...
# 8        NaN          NaN        NaN        NaN        NaN  ...
# 9        NaN          NaN        NaN        NaN        NaN  ...
#
#   user_mentions/43/screen_name user_mentions/44/id_str user_mentions/44/name  \
# 0                          NaN                     NaN                   NaN
# 1                          NaN                     NaN                   NaN
# 2                          NaN                     NaN                   NaN
# 3                          NaN                     NaN                   NaN
# 4                          NaN                     NaN                   NaN
# 5                          NaN                     NaN                   NaN
# 6                          NaN                     NaN                   NaN
# 7                          NaN                     NaN                   NaN
# 8                          NaN                     NaN                   NaN
# 9                          NaN                     NaN                   NaN
#
#   user_mentions/44/screen_name user_mentions/45/id_str user_mentions/45/name  \
# 0                          NaN                     NaN                   NaN
# 1                          NaN                     NaN                   NaN
# 2                          NaN                     NaN                   NaN
# 3                          NaN                     NaN                   NaN
# 4                          NaN                     NaN                   NaN
# 5                          NaN                     NaN                   NaN
# 6                          NaN                     NaN                   NaN
# 7                          NaN                     NaN                   NaN
# 8                          NaN                     NaN                   NaN
# 9                          NaN                     NaN                   NaN
#
#    user_mentions/45/screen_name user_mentions/46/id_str user_mentions/46/name  \
# 0                           NaN                     NaN                   NaN
# 1                           NaN                     NaN                   NaN
# 2                           NaN                     NaN                   NaN
# 3                           NaN                     NaN                   NaN
# 4                           NaN                     NaN                   NaN
# 5                           NaN                     NaN                   NaN
# 6                           NaN                     NaN                   NaN
# 7                           NaN                     NaN                   NaN
# 8                           NaN                     NaN                   NaN
# 9                           NaN                     NaN                   NaN
#
#   user_mentions/46/screen_name
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
#
# [10 rows x 245 columns]

# %%
df = df[['id','full_text', 'speech' ]]

# %%
df.head(10)
# Out:
#                     id                                          full_text  \
# 0  1624652050448674816  another day to hate some kt3umes. they were ne...
# 1  1624649867720007680  #SMG4's:\n Twitter comments               vs  ...
# 2  1624647737039007750  I hate it whenever I see “mataba ka!” comments...
# 3  1624560613807607808  ain’t no way they deleted my comments under th...
# 4  1624540978047553536  Just incase any of you wanna add this one to y...
# 5  1624490492644794370  Honestly done and disappointed with @GenesysGo...
# 6  1624218947242565633  He's A Psycho! - Why David Goggins Records Him...
# 7  1624214848451100677  Comments are fucking horrid on TikTok I hate m...
# 8  1624156000369446912  HELLO??? ALL THE CONCEPT SKETCHES FOR FREE??? ...
# 9  1623653902523441156  I love how much these pics trigger ppl. Going ...
#
#               speech
# 0  hate_or_offensive
# 1  hate_or_offensive
# 2  hate_or_offensive
# 3  hate_or_offensive
# 4  hate_or_offensive
# 5  hate_or_offensive
# 6  hate_or_offensive
# 7  hate_or_offensive
# 8  hate_or_offensive
# 9  hate_or_offensive

# %%
df.loc[df['speech'] == 'normal']
# Out:
#                       id                                          full_text  \
# 0    1624741969045123072  Freedom is poetry, taking liberties with words...
# 1    1624703783115825155  How is going,Biu?Are you passing peacefully an...
# 2    1624745424224411649  u got ball sniffer on your team ofc u would fi...
# 3    1624684918100971521  The sensible normal British public have had en...
# 4    1624659992908382208  There is a conspiracy to declare all concerned...
# ..                   ...                                                ...
# 295  1622461473703215105  My experience online has suggested to me that ...
# 296  1622331473440260098  Bro want the biggest most political arc in rec...
# 297  1622323014971826178  It's comedic how HxH stans only defenses are t...
# 298  1622082249402335234  i have a stutter. you don't really notice it f...
# 299  1540345752463065090  The #DEX butterfly effect: What is the true co...
#
#      speech
# 0    normal
# 1    normal
# 2    normal
# 3    normal
# 4    normal
# ..      ...
# 295  normal
# 296  normal
# 297  normal
# 298  normal
# 299  normal
#
# [895 rows x 3 columns]

# %%
df.loc[df['speech'] == 'hate_or_offensive']
# Out:
#                       id                                          full_text  \
# 0    1624652050448674816  another day to hate some kt3umes. they were ne...
# 1    1624649867720007680  #SMG4's:\n Twitter comments               vs  ...
# 2    1624647737039007750  I hate it whenever I see “mataba ka!” comments...
# 3    1624560613807607808  ain’t no way they deleted my comments under th...
# 4    1624540978047553536  Just incase any of you wanna add this one to y...
# ..                   ...                                                ...
# 217  1622626029658427393  I hate people who only text a couple words at ...
# 218  1622004819811606528  Yemi makes me hate the words “I got you” If a ...
# 219  1621997313123094528  In other words... they hate the truth being to...
# 220  1621886030998814722  In Rajasthan's Barmer, Swami Ramdev was very c...
# 221  1621694830022631424  I hate decor with words written across it with...
#
#                 speech
# 0    hate_or_offensive
# 1    hate_or_offensive
# 2    hate_or_offensive
# 3    hate_or_offensive
# 4    hate_or_offensive
# ..                 ...
# 217  hate_or_offensive
# 218  hate_or_offensive
# 219  hate_or_offensive
# 220  hate_or_offensive
# 221  hate_or_offensive
#
# [966 rows x 3 columns]

# %%
# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Lowercase the text
df['full_text'] = df['full_text'].apply(lambda x: x.lower())

# %%
# Tokenize the text
df['full_text'] = df['full_text'].apply(lambda x: nltk.word_tokenize(x))

# %%
df.head(10)
# Out:
#                     id                                          full_text  \
# 0  1624652050448674816  [another, day, to, hate, some, kt3umes, ., the...
# 1  1624649867720007680  [#, smg4, 's, :, twitter, comments, vs, youtub...
# 2  1624647737039007750  [i, hate, it, whenever, i, see, “, mataba, ka,...
# 3  1624560613807607808  [ain, ’, t, no, way, they, deleted, my, commen...
# 4  1624540978047553536  [just, incase, any, of, you, wan, na, add, thi...
# 5  1624490492644794370  [honestly, done, and, disappointed, with, @, g...
# 6  1624218947242565633  [he, 's, a, psycho, !, -, why, david, goggins,...
# 7  1624214848451100677  [comments, are, fucking, horrid, on, tiktok, i...
# 8  1624156000369446912  [hello, ?, ?, ?, all, the, concept, sketches, ...
# 9  1623653902523441156  [i, love, how, much, these, pics, trigger, ppl...
#
#               speech
# 0  hate_or_offensive
# 1  hate_or_offensive
# 2  hate_or_offensive
# 3  hate_or_offensive
# 4  hate_or_offensive
# 5  hate_or_offensive
# 6  hate_or_offensive
# 7  hate_or_offensive
# 8  hate_or_offensive
# 9  hate_or_offensive

# %%
# Remove stopwords
stop_words = set(stopwords.words('english'))
df['full_text'] = df['full_text'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
# Perform lemmatization
lemmatizer = WordNetLemmatizer()
df['full_text'] = df['full_text'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

# %%
# Remove punctuations and special characters
df['full_text'] = df['full_text'].apply(lambda x: [word for word in x if word.isalnum()])

# %%
# Spell correction
# df['full_text'] = df['full_text'].apply(lambda x: [str(TextBlob(word).correct()) for word in x])

# %%
# Create a feature matrix and target vector
X = df['full_text']
y = df['speech']

# %%
X = [' '.join(x) for x in X]

# %%
# Vectorize the text data
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(X)

# %%
print(X)
# Out:
#   (0, 1010)	1
#   (0, 1823)	1
#   (0, 2299)	1
#   (0, 1750)	1
#   (0, 2100)	1
#   (0, 560)	1
#   (0, 3132)	1
#   (0, 1568)	1
#   (0, 4092)	1
#   (0, 623)	1
#   (0, 2501)	1
#   (0, 1825)	1
#   (0, 821)	1
#   (0, 2577)	1
#   (0, 3574)	1
#   (0, 2144)	1
#   (0, 1691)	1
#   (0, 4164)	1
#   (0, 2392)	1
#   (1, 1823)	1
#   (1, 821)	2
#   (1, 3732)	1
#   (1, 4221)	1
#   (1, 4381)	2
#   (1, 4571)	1
#   :	:
#   (1859, 4569)	1
#   (1859, 2041)	1
#   (1859, 3030)	1
#   (1859, 4020)	1
#   (1859, 3188)	1
#   (1860, 1950)	1
#   (1860, 1303)	1
#   (1860, 1421)	1
#   (1860, 391)	1
#   (1860, 915)	1
#   (1860, 3265)	1
#   (1860, 1448)	1
#   (1860, 1163)	1
#   (1860, 4185)	1
#   (1860, 4505)	1
#   (1860, 1130)	1
#   (1860, 633)	1
#   (1860, 1338)	1
#   (1860, 1438)	1
#   (1860, 1538)	1
#   (1860, 916)	1
#   (1860, 626)	1
#   (1860, 1184)	1
#   (1860, 4250)	1
#   (1860, 524)	1

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Train a Naive Bayes classifier
nb = MultinomialNB()
nb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# Make predictions on the test set
y_pred = nb.predict(X_test)

# %%
# Evaluate the model performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9660107334525939

# %%
# # Preprocess the input text
# input_text = "hello"
# input_text = input_text.lower()
# input_text = nltk.word_tokenize(input_text)
# input_text = [word for word in input_text if word not in stop_words]
# input_text = [lemmatizer.lemmatize(word) for word in input_text]
# input_text = [word for word in input_text if word.isalnum()]
# input_text = [' '.join(input_text)]

# # Vectorize the input text data
# input_text = vectorizer.transform(input_text)

# # Use the trained model to predict the label of the input text data
# y_pred = nb.predict(input_text)

# print(y_pred)

# %%
# Preprocess the custom input text
custom_input = "Bad people"
custom_input = custom_input.lower()
custom_input = nltk.word_tokenize(custom_input)
# custom_input = [word for word in custom_input if word not in stop_words]
# custom_input = [lemmatizer.lemmatize(word) for word in custom_input]
custom_input = [word for word in custom_input if word.isalnum()]
custom_input = [' '.join(custom_input)]

# Vectorize the custom input text
custom_input = vectorizer.transform(custom_input)

# Make a prediction on the custom input text
prediction = nb.predict(custom_input)

# Print the prediction
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-4-9449c3899f5d> in <cell line: 4>()
#       2 custom_input = "Bad people"
#       3 custom_input = custom_input.lower()
# ----> 4 custom_input = nltk.word_tokenize(custom_input)
#       5 # custom_input = [word for word in custom_input if word not in stop_words]
#       6 # custom_input = [lemmatizer.lemmatize(word) for word in custom_input]
#
# /usr/local/lib/python3.9/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /usr/local/lib/python3.9/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#     108
#
# /usr/local/lib/python3.9/dist-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     748
#     749     # Load the resource.
# --> 750     opened_resource = _open(resource_url)
#     751
#     752     if format == "raw":
#
# /usr/local/lib/python3.9/dist-packages/nltk/data.py in _open(resource_url)
#     874
#     875     if protocol is None or protocol.lower() == "nltk":
# --> 876         return find(path_, path + [""]).open()
#     877     elif protocol.lower() == "file":
#     878         # urllib might not use mode='rb', so handle this one ourselves:
#
# /usr/local/lib/python3.9/dist-packages/nltk/data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************
